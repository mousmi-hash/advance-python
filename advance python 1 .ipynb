# %%
s = input("Enter a string: ")
print("Reversed string:", s[::-1])
# Out:
# Enter a string: mousmi
# Reversed string: imsuom

# %%
s = input("Enter a string: ")

upper = 0
lower = 0

for ch in s:
    if ch.isupper():
        upper += 1
    elif ch.islower():
        lower += 1

print("Uppercase letters:", upper)
print("Lowercase letters:", lower)
# Out:
# Enter a string: mosmi
# Uppercase letters: 0
# Lowercase letters: 5

# %%
s = input("Enter a string: ")

if s.isdigit():
    print("The string contains only digits")
else:
    print("The string does not contain only digits")
# Out:
# Enter a string: mousmi
# The string does not contain only digits

# %%
s = input("Enter a string: ")

result = s.replace(" ", "_")
print("Updated string:", result)
# Out:
# Enter a string: mousmi
# Updated string: mousmi

# %%
s = input("Enter a string: ")

for ch in s:
    print(ch, "=", s.count(ch))
# Out:
# Enter a string: naidu
# n = 1
# a = 1
# i = 1
# d = 1
# u = 1

# %%
s = input("Enter a string: ")
ch = input("Enter a character: ")

print("First occurrence:", s.find(ch))
print("Last occurrence:", s.rfind(ch))
# Out:
# Enter a string: nan
# Enter a character: n
# First occurrence: 0
# Last occurrence: 2

# %%
s = input("Enter a string: ")
result = ""

for ch in s:
    if ch not in "aeiouAEIOU":
        result += ch

print("String without vowels:", result)
# Out:
# Enter a string: bhumi
# String without vowels: bhm

# %%
s1 = input("Enter first string: ")
s2 = input("Enter second string: ")

if sorted(s1) == sorted(s2):
    print("The strings are anagrams")
else:
    print("The strings are not anagrams")
# Out:
# Enter first string: jaky
# Enter second string: hod
# The strings are not anagrams

# %%
s = input("Enter a string: ")

print("Updated string:", s.title())
# Out:
# Enter a string: tiles
# Updated string: Tiles

# %%
s = input("Enter a string: ")
flag = True

for i in range(len(s)//2):
    if s[i] != s[len(s)-i-1]:
        flag = False
        break

if flag:
    print("The string is a palindrome")
else:
    print("The string is not a palindrome")
# Out:
# Enter a string: kernel
# The string is not a palindrome

# %%
a = [1,2,3,4]
b = [2,4,6,9]
print(a+b)
# Out:
# [1, 2, 3, 4, 2, 4, 6, 9]

# %%
ndita

# %%
a = set()
b = set()
n = int(input("Enter the number of students: "))
for i in range(n):
    name = input("Enter the name of the student: ")
    if name in a:
        b.add(name)
        print(name, "is FAKE (already exists)")
    else:
        a.add(name)
        print(name, "is REAL (added successfully)")

print("\nReal students:", a)
print("Fake students:", b)
# Out:
# Enter the number of students: 7
# Enter the name of the student: naidu
# naidu is REAL (added successfully)
# Enter the name of the student: nanda
# nanda is REAL (added successfully)
# Enter the name of the student: abhipsa
# abhipsa is REAL (added successfully)
# Enter the name of the student: bhumi
# bhumi is REAL (added successfully)
# Enter the name of the student:
#  is REAL (added successfully)
# Enter the name of the student: mous
# mous is REAL (added successfully)
# Enter the name of the student: nandiota
# nandiota is REAL (added successfully)
#
# Real students: {'', 'bhumi', 'abhipsa', 'nanda', 'nandiota', 'mous', 'naidu'}
# Fake students: set()
